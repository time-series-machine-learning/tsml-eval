# %% [markdown]
# <h1> Diagrams </h1>
#
# To produce diagrams you need result data in either the 'summary df format' or the
# MetricResult format. To get the data in this format see evaluation_metric_results.ipynb.

# %%
import platform

from sktime_estimator_evaluation.evaluation import (
    evaluate_metric_results,
    metric_result_to_summary,
)


def custom_classification(path: str):
    # Check os to determine split value
    if "Windows" in platform.platform():
        split_subdir = path.split("\\")
    else:
        split_subdir = path.split("/")
    metric_name = "ACC"
    file_name_split = split_subdir[-1].split("_")
    estimator_name = file_name_split[0]
    split = file_name_split[0].split("FOLDS")[0].lower()
    return estimator_name, metric_name, split


classification_results = evaluate_metric_results("../results/", custom_classification)


# Both of the above formats are valid. More detail on both can be found in the
# evaluation_metric_result.ipynb notebook.

# %%
# Critical difference diagrams
from sktime_estimator_evaluation.evaluation.diagrams import critical_difference_diagram

figures = critical_difference_diagram(classification_results)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [2], line 4
#       1 # Critical difference diagrams
#       2 from sktime_estimator_evaluation.evaluation.diagrams import critical_difference_diagram
# ----> 4 figures = critical_difference_diagram(classification_results)
#
# File ~\Projects\sktime-estimator-evaluation\sktime_estimator_evaluation\evaluation\diagrams\_critical_difference_diagram.py:79, in critical_difference_diagram(metric_results, output_path, title, alpha, color, space_between_labels, fontsize, title_fontsize, figure_width, figure_height)
#      22 def critical_difference_diagram(
#      23     metric_results: Union[pd.DataFrame, List[MetricResults]],
#      24     output_path=None,
#    (...)
#      32     figure_height: float = None,
#      33 ) -> Union[plt.Figure, List[plt.Figure]]:
#      34     """Create a critical difference diagram.
#      35
#      36     Parameters
#    (...)
#      77         figures is return else plt.Figure is returned.
#      78     """
# ---> 79     df = metric_result_to_df(metric_results)
#      80     num_metrics = len(df.columns) - 2
#      81     figures = []
#
# File ~\Projects\sktime-estimator-evaluation\sktime_estimator_evaluation\evaluation\diagrams\_utils.py:38, in metric_result_to_df(result)
#      35 if not isinstance(result, pd.DataFrame):
#      36     df = metric_result_to_summary(result)
# ---> 38 df = _check_df(df)
#      39 return df
#
# File ~\Projects\sktime-estimator-evaluation\sktime_estimator_evaluation\evaluation\diagrams\_utils.py:55, in _check_df(df)
#      42 def _check_df(df: pd.DataFrame) -> pd.DataFrame:
#      43     """Check if data frame is valid.
#      44
#      45     Parameters
#    (...)
#      53         Validated dataframe
#      54     """
# ---> 55     datasets = set((df.iloc[:, 1]).unique())
#      56     estimators = (df.iloc[:, 0]).unique()
#      57     if not isinstance(df, pd.DataFrame):
#
# AttributeError: 'tuple' object has no attribute 'iloc'

# %%
# Scatter diagrams
from sktime_estimator_evaluation.evaluation.diagrams import scatter_diagram

# By default the scatter diagram if not specified will be a scatter plot of EVERY,
# combination of estimator and metric. To only show a subset of the estimators and
# metrics we can specify which to compare and from
figures = scatter_diagram(classification_results, compare_estimators_to=["HC2"])
