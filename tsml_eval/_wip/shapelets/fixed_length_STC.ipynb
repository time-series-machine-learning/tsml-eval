# %%
from tsml.datasets import load_minimal_chinatown
from tsml_eval._wip.shapelets.transformations.collection.shapelet_based._dilated_shapelet_transform import RandomDilatedShapeletTransform
from tsml_eval._wip.shapelets.classification.shapelet_based._dstc import DilatedShapeletTransformClassifier
X_train, y_train = load_minimal_chinatown(split="TRAIN")
X_test, y_test = load_minimal_chinatown(split="TEST")
flt = RandomDilatedShapeletTransform()
fltc = DilatedShapeletTransformClassifier().fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\ProgramData\miniconda3\envs\tsml-eval\Lib\site-packages\numba\core\caching.py:469, in IndexDataCacheFile.save(self, key, data)
#     467 try:
#     468     # If key already exists, we will overwrite the file
# --> 469     data_name = overloads[key]
#     470 except KeyError:
#     471     # Find an available name for the data file
#
# KeyError: ((ListType(Tuple(float64, int64, int64, int64, int64, int64, int64)),), ('x86_64-pc-windows-msvc', 'skylake', '+64bit,+adx,+aes,-amx-bf16,-amx-int8,-amx-tile,+avx,+avx2,-avx512bf16,-avx512bitalg,-avx512bw,-avx512cd,-avx512dq,-avx512er,-avx512f,-avx512fp16,-avx512ifma,-avx512pf,-avx512vbmi,-avx512vbmi2,-avx512vl,-avx512vnni,-avx512vp2intersect,-avx512vpopcntdq,-avxvnni,+bmi,+bmi2,-cldemote,+clflushopt,-clwb,-clzero,+cmov,+crc32,+cx16,+cx8,-enqcmd,+f16c,+fma,-fma4,+fsgsbase,+fxsr,-gfni,-hreset,+invpcid,-kl,-lwp,+lzcnt,+mmx,+movbe,-movdir64b,-movdiri,-mwaitx,+pclmul,-pconfig,-pku,+popcnt,-prefetchwt1,+prfchw,-ptwrite,-rdpid,+rdrnd,+rdseed,-rtm,+sahf,-serialize,+sgx,-sha,-shstk,+sse,+sse2,+sse3,+sse4.1,+sse4.2,-sse4a,+ssse3,-tbm,-tsxldtrk,-uintr,-vaes,-vpclmulqdq,-waitpkg,-wbnoinvd,-widekl,-xop,+xsave,+xsavec,+xsaveopt,+xsaves'), ('d0a96609cf4b4631f83ad901ce4e5057c3cd0c9b55b7c49b4fe41cbadf904ba7', 'e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855'))
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 7
#       5 X_test, y_test = load_minimal_chinatown(split="TEST")
#       6 flt = RandomDilatedShapeletTransform()
# ----> 7 fltc = DilatedShapeletTransformClassifier().fit(X_train,y_train)
#
# File c:\ProgramData\miniconda3\envs\tsml-eval\Lib\site-packages\aeon\classification\base.py:133, in BaseClassifier.fit(self, X, y)
#     130 X, y, single_class = self._fit_setup(X, y)
#     132 if not single_class:
# --> 133     self._fit(X, y)
#     135 self.fit_time_ = int(round(time.time() * 1000)) - start
#     136 # this should happen last
#
# File ~\OneDrive - University of Southampton\Documents\Vanya's Directory\tsml-eval\tsml_eval\_wip\shapelets\classification\shapelet_based\_dstc.py:197, in DilatedShapeletTransformClassifier._fit(self, X, y)
#     177 def _fit(self, X, y):
#     178     """Fit ShapeletTransformClassifier to training data.
#     179
#     180     Parameters
#    (...)
#     195     ending in "_".
#     196     """
# --> 197     X_t = self._fit_stc_shared(X, y)
#     198     self._estimator.fit(X_t, y)
#     199     return self
#
# File ~\OneDrive - University of Southampton\Documents\Vanya's Directory\tsml-eval\tsml_eval\_wip\shapelets\classification\shapelet_based\_dstc.py:327, in DilatedShapeletTransformClassifier._fit_stc_shared(self, X, y)
#     324 if m is not None and self.time_limit_in_minutes > 0:
#     325     self._estimator.time_limit_in_minutes = self._classifier_limit_in_minutes
# --> 327 return self._transformer.fit_transform(X, y)
#
# File c:\ProgramData\miniconda3\envs\tsml-eval\Lib\site-packages\aeon\transformations\collection\base.py:208, in BaseCollectionTransformer.fit_transform(self, X, y)
#     206 X_inner = self._preprocess_collection(X)
#     207 y_inner = y
# --> 208 Xt = self._fit_transform(X=X_inner, y=y_inner)
#     210 self._is_fitted = True
#     212 return Xt
#
# File c:\ProgramData\miniconda3\envs\tsml-eval\Lib\site-packages\aeon\transformations\collection\base.py:409, in BaseCollectionTransformer._fit_transform(self, X, y)
#     390 """Fit to data, then transform it.
#     391
#     392 Fits the transformer to X and y and returns a transformed version of X.
#    (...)
#     405 transformed version of X.
#     406 """
#     407 # Non-optimized default implementation; override when a better
#     408 # method is possible for a given algorithm.
# --> 409 self._fit(X, y)
#     410 return self._transform(X, y)
#
# File ~\OneDrive - University of Southampton\Documents\Vanya's Directory\tsml-eval\tsml_eval\_wip\shapelets\transformations\collection\shapelet_based\_dilated_shapelet_transform.py:347, in RandomDilatedShapeletTransform._fit(self, X, y)
#     345 if self.remove_self_similar:
#     346     for i, heap in enumerate(shapelets):
# --> 347         to_keep = self._remove_self_similar_shapelets(heap)
#     348         shapelets[i] = List([n for (n, b) in zip(heap, to_keep) if b])
#     350 n_shapelets_extracted += n_shapelets_to_extract
#
# File c:\ProgramData\miniconda3\envs\tsml-eval\Lib\site-packages\numba\core\dispatcher.py:487, in _DispatcherBase._compile_for_args(self, *args, **kws)
#     485             e.patch_message('\n'.join((str(e).rstrip(), help_msg)))
#     486     # ignore the FULL_TRACEBACKS config, this needs reporting!
# --> 487     raise e
#     488 finally:
#     489     self._types_active_call = []
#
# File c:\ProgramData\miniconda3\envs\tsml-eval\Lib\site-packages\numba\core\dispatcher.py:420, in _DispatcherBase._compile_for_args(self, *args, **kws)
#     418 return_val = None
#     419 try:
# --> 420     return_val = self.compile(tuple(argtypes))
#     421 except errors.ForceLiteralArg as e:
#     422     # Received request for compiler re-entry with the list of arguments
#     423     # indicated by e.requested_args.
#     424     # First, check if any of these args are already Literal-ized
#     425     already_lit_pos = [i for i in e.requested_args
#     426                        if isinstance(args[i], types.Literal)]
#
# File c:\ProgramData\miniconda3\envs\tsml-eval\Lib\site-packages\numba\core\dispatcher.py:964, in Dispatcher.compile(self, sig)
#     962         raise e.bind_fold_arguments(folded)
#     963     self.add_overload(cres)
# --> 964 self._cache.save_overload(sig, cres)
#     965 return cres.entry_point
#
# File c:\ProgramData\miniconda3\envs\tsml-eval\Lib\site-packages\numba\core\caching.py:652, in Cache.save_overload(self, sig, data)
#     648 """
#     649 Save the data for the given signature in the cache.
#     650 """
#     651 with self._guard_against_spurious_io_errors():
# --> 652     self._save_overload(sig, data)
#
# File c:\ProgramData\miniconda3\envs\tsml-eval\Lib\site-packages\numba\core\caching.py:662, in Cache._save_overload(self, sig, data)
#     660 key = self._index_key(sig, data.codegen)
#     661 data = self._impl.reduce(data)
# --> 662 self._cache_file.save(key, data)
#
# File c:\ProgramData\miniconda3\envs\tsml-eval\Lib\site-packages\numba\core\caching.py:478, in IndexDataCacheFile.save(self, key, data)
#     476             break
#     477     overloads[key] = data_name
# --> 478     self._save_index(overloads)
#     479 self._save_data(data_name, data)
#
# File c:\ProgramData\miniconda3\envs\tsml-eval\Lib\site-packages\numba\core\caching.py:523, in IndexDataCacheFile._save_index(self, overloads)
#     521 data = self._source_stamp, overloads
#     522 data = self._dump(data)
# --> 523 with self._open_for_write(self._index_path) as f:
#     524     pickle.dump(self._version, f, protocol=-1)
#     525     f.write(data)
#
# File c:\ProgramData\miniconda3\envs\tsml-eval\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\ProgramData\miniconda3\envs\tsml-eval\Lib\site-packages\numba\core\caching.py:561, in IndexDataCacheFile._open_for_write(self, filepath)
#     559 tmpname = '%s.tmp.%s' % (filepath, uid)
#     560 try:
# --> 561     with open(tmpname, "wb") as f:
#     562         yield f
#     563     os.replace(tmpname, filepath)
#
# FileNotFoundError: [Errno 2] No such file or directory: "C:\\Users\\vanya\\OneDrive - University of Southampton\\Documents\\Vanya's Directory\\tsml-eval\\tsml_eval\\_wip\\shapelets\\transformations\\collection\\shapelet_based\\__pycache__\\_dilated_shapelet_transform.RandomDilatedShapeletTransform._remove_self_similar_shapelets-658.py312.nbi.tmp.78bf5f819d364d5d"
